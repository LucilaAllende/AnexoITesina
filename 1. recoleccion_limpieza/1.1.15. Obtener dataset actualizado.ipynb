# %% [markdown]
# # 1.1.15. Obtener dataset actualizado

# %% [markdown]
# Al tener acceso a las encuestas ganaderas realizadas en la provincia de Chubut se pudieron recolectaron nuevos datos, que nos permitieron actualizar las métricas relacionadas con las existencias ovinas, la cantidad de kilogramos de lana y la finura y el rinde de la misma. Este proceso se llevó a cabo en tres etapas: primero se actualizó la información sobre las existencias, luego se actualizó la cantidad de kilogramos de lana y finalmente se actualizó la información sobre la finura y el rinde de la lana.
#
# Por lo tanto, hemos generado un nuevo conjunto de datos que se cargará y se guardará como archivo csv. Antes de guardar, se eliminaron las columnas intermedias que utilizamos para identificar y calcular la información actualizada, como el estado de los animales y los kilogramos por animal utilizados para calcular la cantidad de lana. Así, obtenemos un dataset más completo y preciso para el análisis y entrenamiento de modelos.

# %%
import pandas as pd

# %%
datos = pd.read_csv("datos_lana/dataset_aplicado_%_lana_f_r.csv")
datos
# Out:
#           fecha provincia       estado departamento  carneros  ovejas  \
# 0    2012-12-31    CHUBUT  MODIFICABLE       BIEDMA      2740   52320
# 1    2013-12-31    CHUBUT         REAL       BIEDMA      3925   70677
# 2    2014-12-31    CHUBUT         REAL       BIEDMA      3223   61195
# 3    2015-12-31    CHUBUT  MODIFICABLE       BIEDMA      3885   67528
# 4    2016-12-31    CHUBUT  MODIFICABLE       BIEDMA      3743   70451
# ..          ...       ...          ...          ...       ...     ...
# 159  2016-12-31    CHUBUT  MODIFICABLE       TELSEN      4711   74125
# 160  2017-12-31    CHUBUT  MODIFICABLE       TELSEN      4496   71149
# 161  2018-12-31    CHUBUT  MODIFICABLE       TELSEN      4634   74179
# 162  2019-12-31    CHUBUT  MODIFICABLE       TELSEN      4305   72515
# 163  2020-12-31    CHUBUT  MODIFICABLE       TELSEN      4416   70736
#
#      borregos  capones  corderos_corderas  total_ovinos  kilos_lana  \
# ...

# %%
datos = datos.drop(['estado', 'kilos_animal'], axis=1)
datos
# Out:
#           fecha provincia departamento  carneros  ovejas  borregos  capones  \
# 0    2012-12-31    CHUBUT       BIEDMA      2740   52320     22319    25489
# 1    2013-12-31    CHUBUT       BIEDMA      3925   70677     27227    33389
# 2    2014-12-31    CHUBUT       BIEDMA      3223   61195     29491    29688
# 3    2015-12-31    CHUBUT       BIEDMA      3885   67528     28319    33296
# 4    2016-12-31    CHUBUT       BIEDMA      3743   70451     30050    33038
# ..          ...       ...          ...       ...     ...       ...      ...
# 159  2016-12-31    CHUBUT       TELSEN      4711   74125     28715    31728
# 160  2017-12-31    CHUBUT       TELSEN      4496   71149     27574    28606
# 161  2018-12-31    CHUBUT       TELSEN      4634   74179     28793    35979
# 162  2019-12-31    CHUBUT       TELSEN      4305   72515     27648    35273
# 163  2020-12-31    CHUBUT       TELSEN      4416   70736     27084    31418
#
# ...

# %%
datos.to_csv("dataset_produccion_clima_chubut_actualizado.csv", index=False)
