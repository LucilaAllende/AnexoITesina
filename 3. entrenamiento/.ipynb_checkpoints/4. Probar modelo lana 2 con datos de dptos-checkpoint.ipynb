# %%
from statsmodels.iolib.smpickle import load_pickle
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

# %%
modelo_lana = load_pickle('modelos/modelo_prediccion_lana_3')

# %% [markdown]
# ## Prueba con una tupla

# %% [markdown]
# Se tomo las primeras dos filas del dataset *datos_dptp_ha.csv*, que son filas corresponfientes a Biedma.

# %% [markdown]
# | total_ovinos | kilos_lana | cant_lluvia |
# | --- | --- | --- |
# | 193849 | 649130.0 | 46.40 |
# | 187897 | 620176.0 | 226.50 |

# %%
resultado_prediccion = modelo_lana.predict([[46.40,193849], [226.50,187897]])
resultado_prediccion
# Out:
# /home/lucila/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[689575.71534584],
#        [662003.63200993]])

# %%
dato_real =[[649130.0],[620176.0]]

# %%
print('Exactitud de la predicción:')
print(str(round(r2_score(dato_real, resultado_prediccion),4)))
# Out:
# Exactitud de la predicción:
# -7.0765

# %%
print('MSE:')
print(str(round(mean_squared_error(dato_real, resultado_prediccion),4)))
# Out:
# MSE:
# 1692703344.6976

# %%
plt.plot(range(len(dato_real)),dato_real,label="Real")
plt.plot(range(len(resultado_prediccion)),resultado_prediccion,label="Prediccion")
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
plt.xlabel('muestras')
plt.ylabel('kilos lana')
plt.legend()
plt.show()

# %% [markdown]
# ## Prueba con datos varios

# %%
data = pd.read_csv("datos/datos_dptos_reales_reducidos.csv")
data
# Out:
#          fecha provincia         departamento  carneros  ovejas  borregos  \
# 0   2012-12-31    CHUBUT               BIEDMA      5785   93378     30168
# 1   2014-12-31    CHUBUT               BIEDMA      4785   82706     29379
# 2   2020-12-31    CHUBUT               BIEDMA      3084   82806     29134
# 3   2013-12-31    CHUBUT             CUSHAMEN     12516  125655     31127
# 4   2014-12-31    CHUBUT             CUSHAMEN      6525  120803     33531
# 5   2015-12-31    CHUBUT             CUSHAMEN      5764  115205     30865
# 6   2020-12-31    CHUBUT             CUSHAMEN      5385  124862     33570
# 7   2014-12-31    CHUBUT  FLORENTINO AMEGHINO      9623  128662     54128
# 8   2016-12-31    CHUBUT  FLORENTINO AMEGHINO     11974  159866     63418
# 9   2017-12-31    CHUBUT  FLORENTINO AMEGHINO     12216  157416     59969
# 10  2007-12-31    CHUBUT            FUTALEUFU      5129   81560     24740
# 11  2008-12-31    CHUBUT            FUTALEUFU      5639   90494     30119
# 12  2009-12-31    CHUBUT            FUTALEUFU      5155   85752     28633
# 13  2020-12-31    CHUBUT               GAIMAN      5295  197372     27275
# 14  2012-12-31    CHUBUT            LANGUIÑEO      8550  141153     52659
# 15  2016-12-31    CHUBUT            LANGUIÑEO      7588  112547     47178
# 16  2017-12-31    CHUBUT       PASO DE INDIOS      7789  128838     43440
# 17  2018-12-31    CHUBUT       PASO DE INDIOS      8198  128880     47244
# 18  2000-12-31    CHUBUT               RAWSON      2355   57320     20632
#
#     cant_lluvia  tem_max  temp_media  temp_min
# 0         46.40    18.10       12.40      6.70
# 1        331.30    20.60       14.70      9.20
# 2        191.40    20.50       14.60      9.20
# 3        769.59    18.90       11.88      5.49
# 4        640.40    17.03       10.46      4.62
# 5        756.57    18.92       11.99      5.68
# 6        131.40    25.22       15.62      5.92
# 7        174.10    16.90       10.70      4.30
# 8         77.85    20.30       14.20      8.25
# 9        336.93    20.00       13.80      8.10
# 10       327.20    16.45        9.50      2.35
# 11       614.80    18.85       11.05      2.70
# 12       386.47    15.23        8.73      2.37
# 13        57.87    23.14       13.90      5.30
# 14       157.35    19.80       11.40      3.00
# 15       124.87    14.50        7.77      1.50
# 16        66.70    21.60       14.20      7.10
# 17       238.60    26.60       18.00      9.20
# 18       212.60    23.00       14.10      5.50
# 19        93.20    21.70       13.90      6.00
# 20       170.80    21.40       13.70      5.90
# 21        92.00    22.10       14.40      6.70
# 22       126.20    15.93        9.77      2.90
# 23       176.43    14.57        8.50      2.47
# 24       123.17    15.80        9.40      3.47
# 25        88.90    20.15       13.60      7.50
# 26        69.45    20.35       13.95      8.15
# 27       340.60    13.60        7.60      1.70
# 28       295.27    10.83        5.33      0.47
# 29       273.33    17.47       11.57      5.77
# 30       220.03    16.60       10.93      5.03

# %%
X = data[["cant_lluvia", "total_ovinos"]]
y = data[['kilos_lana']]

# %%
resultado_prediccion = modelo_lana.predict(X)
resultado_prediccion
# Out:
# array([[ 689575.71534584],
#        [ 636896.90183784],
#        [ 613504.81126623],
#        [ 780803.04161823],
#        [ 803057.60980868],
#        [ 740935.05187768],
#        [ 869509.6334076 ],
#        [1004247.31741051],
#        [1105275.57232961],
#        [1163408.2216958 ],
#        [ 523130.6226936 ],
#        [ 617220.21081989],
#        [ 592064.74792258],
#        [1141006.42464463],
#        [1075858.91956482],
#        [ 833252.3805151 ],
#        [ 944991.4660973 ],
#        [ 972677.22545541],
#        [ 429179.10267051],
#        [ 468155.63697124],
#        [ 479449.37003754],
#        [ 478311.6041238 ],
#        [2877237.69042109],
#        [2708075.16327206],
#        [2824811.31361552],
#        [ 718208.25899698],
#        [ 747479.82711923],
#        [2075040.3617751 ],
#        [2109591.56455128],
#        [ 599967.12444917],
#        [ 575210.07337187]])

# %%
print('Exactitud de la predicción:')
print(str(round(r2_score(y, resultado_prediccion),4)))
# Out:
# Exactitud de la predicción:
# 0.9186

# %%
print('MSE:')
print(str(round(mean_squared_error(y, resultado_prediccion),4)))
# Out:
# MSE:
# 55185042714.7325

# %%
plt.plot(range(len(y)),y,label="Real")
plt.plot(range(len(resultado_prediccion)),resultado_prediccion,label="Prediccion")
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
plt.xlabel('muestras')
plt.ylabel('kilos lana')
plt.legend()
plt.show()
