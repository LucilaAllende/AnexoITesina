# %% [markdown]
# # 3.13. Modelo de corderos seleccionado

# %% [markdown]
# Después de realizar una comparación, el modelo que mejor funciono fue el 3, entrenado con los datos de departamentos de Chubut actualizados con los datos de las encuestas; que si bien en un principio parecía tener overfit debido a las altas métricas fue capaz de generelizar bastante bien para datos que no conocía y fue el que obtuvo mayor puntaje. Por lo tanto es el que va ser utilizado en la aplicación.

# %% [markdown]
# En la siguiente celda de código, se importarán varias librerías, entre ellas:
#
# - Pandas para manejar los datos a través de DataFrames.
# - Matplotlib y Seaborn se utilizarán para visualizar los resultados de las predicciones mediante gráficos.
# - De Scikit-learn se utilizarán la  métricas **r2_score**.
# - Por último, se usará load_pickle para recuperar el modelo entrenado guardado previamente.

# %%
import pandas as pd
import seaborn as snsº
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from statsmodels.iolib.smpickle import load_pickle

# %% [markdown]
# Cargamos el modelo para mostrar como se vería en la aplicación.

# %%
modelo_corderos = load_pickle('modelos/modelo_prediccion_corderos_3')

# %% [markdown]
# Se creo un modelo con datos aleatorios del dataset 1 y 2, para ver con un conjunto de datos cuál sería el resultado.

# %%
data = pd.read_csv("datos/datos_reducidos_corderos.csv")
data
# Out:
#          fecha provincia         departamento  carneros  ovejas  borregos  \
# 0   2012-12-31    CHUBUT               BIEDMA      2740   52320     22319
# 1   2013-12-31    CHUBUT               BIEDMA      3925   70677     27227
# 2   2019-12-31    CHUBUT               BIEDMA      3606   70938     32085
# 3   2020-12-31    CHUBUT               BIEDMA      3084   82806     29134
# 4   2008-12-31    CHUBUT             CUSHAMEN      4578   86402     28200
# 5   2013-12-31    CHUBUT             CUSHAMEN      4751   85946     26255
# 6   2014-12-31    CHUBUT             CUSHAMEN      4198   77263     26512
# 7   2015-12-31    CHUBUT             CUSHAMEN      5377   99927     33404
# 8   2020-12-31    CHUBUT             CUSHAMEN      5385  124862     33570
# 9   2009-12-31    CHUBUT  FLORENTINO AMEGHINO      7970  131131     56083
# 10  2014-12-31    CHUBUT  FLORENTINO AMEGHINO      8893  140928     56282
# 11  2016-12-31    CHUBUT  FLORENTINO AMEGHINO      7745  122098     55202
# 12  2017-12-31    CHUBUT  FLORENTINO AMEGHINO      8064  131186     54791
# 13  2007-12-31    CHUBUT            FUTALEUFU      5129   81560     24740
# 14  2008-12-31    CHUBUT            FUTALEUFU      5639   90494     30119
# 15  2009-12-31    CHUBUT            FUTALEUFU      5155   85752     28633
# 16  2019-12-31    CHUBUT            FUTALEUFU      3775   56479     14981
# 17  2014-12-31    CHUBUT               GAIMAN      4936   90039     27772
# 18  2020-12-31    CHUBUT               GAIMAN      5295  197372     27275
# 19  2012-12-31    CHUBUT            LANGUIÑEO      8550  141153     52659
# 20  2016-12-31    CHUBUT            LANGUIÑEO      7588  112547     47178
# 21  2017-12-31    CHUBUT       PASO DE INDIOS      6908  117620     39207
# 27    19267       22102        135796   205200.00   19.57  61.66    54.50
# 28    92579      139943        625824  2360088.00   20.21  57.80    55.75
# 29    82269      126654        567512  2188059.00   20.24  57.57    59.15
# 30    80243      122691        552517  2146504.00   20.14  58.89    58.70
# 31    30644       32877        181425   663376.00   20.73  49.13    51.20
# 32    32012       37346        182358   694471.00   19.92  48.21    48.90
# 33    31383       33832        176065   635594.65   20.12  48.52    62.83
# 34   126501      109720        580093  3045600.00   19.15  61.75    71.90
# 35   130175      100704        589234  2413920.00   18.62  61.43    77.00
# 36    29821       35267        175016   638808.40   20.00  53.06    46.73
# 37    39243       20290        171162   637000.00   20.20  53.55    50.80
# 38    36570       17750        163812   637000.00   19.11  56.01    47.17
#
#     cant_lluvia  tem_max  temp_media  temp_min
# 0         46.40    18.10       12.40      6.70
# 1        226.50    19.90       14.20      8.80
# 2        295.50    18.70       13.60      8.70
# 3        191.40    20.50       14.60      9.20
# 4        304.50    19.85       12.20      4.10
# 5        769.59    18.90       11.88      5.49
# 6        640.40    17.03       10.46      4.62
# 7        756.57    18.92       11.99      5.68
# 8        131.40    25.22       15.62      5.92
# 9        137.70    20.40       12.90      5.70
# 10       174.10    16.90       10.70      4.30
# 11        77.85    20.30       14.20      8.25
# 12       336.93    20.00       13.80      8.10
# 13       327.20    16.45        9.50      2.35
# 14       614.80    18.85       11.05      2.70
# 15       386.47    15.23        8.73      2.37
# 16       272.60    20.97       13.00      4.40
# 17       137.93    20.47       13.07      5.83
# 18        57.87    23.14       13.90      5.30
# 19       157.35    19.80       11.40      3.00
# 20       124.87    14.50        7.77      1.50
# 21        66.70    21.60       14.20      7.10
# 22       238.60    26.60       18.00      9.20
# 23       212.60    23.00       14.10      5.50
# 24       143.90    22.50       12.90      4.90
# 25        93.20    21.70       13.90      6.00
# 26       170.80    21.40       13.70      5.90
# 27        92.00    22.10       14.40      6.70
# 28       126.20    15.93        9.77      2.90
# 29       176.43    14.57        8.50      2.47
# 30       123.17    15.80        9.40      3.47
# 31        88.90    20.15       13.60      7.50
# 32        69.45    20.35       13.95      8.15
# 33       196.47    13.90        8.87      3.77
# 34       340.60    13.60        7.60      1.70
# 35       295.27    10.83        5.33      0.47
# 36       146.10    17.77       11.60      5.40
# 37       273.33    17.47       11.57      5.77
# 38       220.03    16.60       10.93      5.03

# %%
X = data[['cant_lluvia', 'ovejas']]
y = data[['cordero/as']]

# %%
resultado_prediccion = modelo_corderos.predict(X)

# %%
'Score o R2 de la predicción: {:.2%}'.format(r2_score(y, resultado_prediccion))
# Out:
# 'Score o R2 de la predicción: 75.60%'

# %%
plt.plot(range(len(y)),y,label="Real")
plt.plot(range(len(resultado_prediccion)),resultado_prediccion,label="Prediccion")
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
plt.xlabel('muestras')
plt.ylabel('corderos')
plt.legend()
plt.show()

# %% [markdown]
# Vemos que el modelo predice bien con un 92% de exactitud.
